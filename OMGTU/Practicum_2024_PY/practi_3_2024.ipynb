# %%
import numpy as np
import matplotlib.pyplot as plt

#1
print("П.1")


def y(x):
    return np.log(np.sqrt(x))


a, b = 1, 6  # границы интегрирования
num_points = 100

x = np.linspace(a, b, num_points)
os_y = y(x)
# Out:
# П.1

# %%
#2
print("П.2")

plt.figure(figsize=(10,6))
plt.plot(x, os_y, label="y(x) = ln(√(x))", color="b")

plt.title("График функции $y(x) = ln(√(x))$", fontsize=16)
plt.xlabel("x", fontsize=14)
plt.ylabel("y", fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)
plt.show()
# Out:
# П.2

# %%
#3
print("П.3")

plt.figure(figsize=(10,6))
plt.scatter(x, os_y, label="y(x) = ln(√(x))", color=(0, 0, 0))

plt.title("График функции $y(x) = ln(√(x))$", fontsize=16)
plt.xlabel("x", fontsize=14)
plt.ylabel("y", fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)
plt.show()
# Out:
# П.2

# %%
#4
print("П.4")
distrib_uniform = np.random.randint(1, 101, 100)
distrib_normal = np.round(np.random.normal(50, 10, 100)).astype(int)
print("Равномерное распределение:\n", *distrib_uniform)
print("Нормальное распределение:\n", *distrib_normal)
# Out:
# П.4
# Равномерное распределение:
#  28 4 100 55 69 99 43 64 27 64 16 68 83 53 64 61 38 87 50 25 78 1 28 81 97 81 41 20 95 53 92 54 74 3 97 27 25 60 53 55 34 13 30 33 46 82 54 100 51 11 34 52 67 35 43 63 90 45 1 95 57 79 33 72 8 47 88 87 44 84 33 17 34 59 75 17 11 23 9 32 32 35 74 13 54 61 56 5 14 38 7 59 14 48 8 47 2 30 18 60
# Нормальное распределение:
#  52 48 38 60 50 47 55 60 44 47 48 55 55 26 63 42 52 47 29 45 52 59 68 36 23 51 60 54 40 54 51 53 50 56 49 56 56 47 55 57 58 81 67 50 50 47 67 51 44 47 50 39 41 43 25 46 56 28 57 48 44 56 55 32 54 50 61 40 60 49 54 50 64 64 42 34 63 60 41 65 52 45 39 37 38 42 48 71 39 41 58 43 56 36 30 55 39 52 62 65

# %%
from statistics import mode, median

#5
print("П.5")
print("a.")
print("Среднее для равномерного: ", np.mean(distrib_uniform))
print("Среднее для нормального: ", np.mean(distrib_normal))
print("\nb.")
print("Мода для равномерного: ", mode(distrib_uniform))
print("Мода для нормального: ", mode(distrib_normal))
print("\nc.")
print("Медиана для равномерного: ", median(distrib_uniform))
print("Медиана для нормального: ", median(distrib_normal))
print("\nd.")
print("Минимум для равномерного: ", np.min(distrib_uniform))
print("Минимум для нормального: ", np.min(distrib_normal))
print("\ne.")
print("Максимум для равномерного: ", np.max(distrib_uniform))
print("Максимум для нормального: ", np.max(distrib_normal))
print("\nf.")
print("Стандартное отклонение для равномерного: ", np.std(distrib_uniform))
print("Стандартное отклонение для нормального: ", np.std(distrib_normal))
# Out:
# П.5
# a.
# Среднее для равномерного:  47.76
# Среднее для нормального:  49.71
#
# b.
# Мода для равномерного:  64
# Мода для нормального:  50
#
# c.
# Медиана для равномерного:  47.5
# Медиана для нормального:  50.0
#
# d.
# Минимум для равномерного:  1
# Минимум для нормального:  23
#
# e.
# Максимум для равномерного:  100
# Максимум для нормального:  81
#
# f.
# Стандартное отклонение для равномерного:  27.710691077632838
# Стандартное отклонение для нормального:  10.562476035475774

# %%
from scipy import stats

#6
print("П.6")
chi2, p_value = stats.chisquare(np.bincount(distrib_uniform)) #bincount подсчитывает кол-во вхождений каждого целого числа
print(f"p-value: {p_value}")
# Out:
# П.6
# p-value: 0.9076787849254528
